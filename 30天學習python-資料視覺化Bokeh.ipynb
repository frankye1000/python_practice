# %% [markdown]
# 我們前兩天討論的 matplotlib 與 Seaborn 套件基本上已經可以滿足絕大多數的繪圖需求，唯一美中不足的一點是這些圖形都是靜態（Static）的，如果我們想要讓這些圖形帶有一點互動（Interactive），像是滑鼠游標移上去會顯示資料點的數據或可以縮放圖形等基於 JavaScript 的效果，我們可以在 Python 使用 Bokeh 這個高階繪圖套件來達成。

# %%
#使用 bokeh.charts 的 Histogram() 方法。
from bokeh.charts import Histogram, show, output_notebook
import numpy as np
output_notebook()
normal_samples = np.random.normal(size = 100000)
hist = Histogram(normal_samples)
show(hist)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c8f82860-2ad7-4cca-a214-cc9e93c82749">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b116be93-21d2-4ad1-a1d9-55f9e9329bce"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b116be93-21d2-4ad1-a1d9-55f9e9329bce");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b116be93-21d2-4ad1-a1d9-55f9e9329bce");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b116be93-21d2-4ad1-a1d9-55f9e9329bce' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0423af9f-bef8-463d-872d-98e245a0860e":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(2.371086, 2.428971]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[146.0],"label":["(2.371086, 2.428971]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.05788470391932865],"x":["2.4000285000000003"],"y":[73.0]}},"id":"c1ba12d6-ea19-4be3-89f1-295b11f7feae","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"09f88ed7-2c02-4c99-8605-b551e0f35cc4","type":"Rect"},{"attributes":{"data_source":{"id":"5fb3cb06-1d89-4a9d-ad30-5c0f122db841","type":"ColumnDataSource"},"glyph":{"id":"15469a6f-07cf-4afe-827d-a29372077164","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"56e06aee-e02c-4926-bf39-f2139aafafa1","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(2.602625, 2.660510]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[65.0],"label":["(2.602625, 2.660510]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.05788470391932954],"x":["2.6315675"],"y":[32.5]}},"id":"9f76ecb3-3adc-4e29-8dae-a7089d377dbe","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3c66dbd6-18b0-4578-a610-b064e29ef02d","type":"ColumnDataSource"},"glyph":{"id":"0b01b513-160d-44ee-93d5-d746e118db83","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"b4b92a63-8d41-4781-88e4-a920d29032b3","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c1ba12d6-ea19-4be3-89f1-295b11f7feae","type":"ColumnDataSource"},"glyph":{"id":"09f88ed7-2c02-4c99-8605-b551e0f35cc4","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"616d2d30-a162-48d4-b511-6b21b5c584f6","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d9624ac0-2200-443a-b301-1e921340ceb2","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(2.544740, 2.602625]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[87.0],"label":["(2.544740, 2.602625]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.05788470391932954],"x":["2.5736825000000003"],"y":[43.5]}},"id":"cc6f7cc8-5fec-4c9d-9eb7-7f8c0ab79482","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"22850ac7-ee31-464d-90e8-94c18b685353","type":"Rect"},{"attributes":{"data_source":{"id":"cc6f7cc8-5fec-4c9d-9eb7-7f8c0ab79482","type":"ColumnDataSource"},"glyph":{"id":"d9624ac0-2200-443a-b301-1e921340ceb2","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"5aa5150e-d509-435a-b7ec-7e469e058184","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"deb2c8dc-6f1c-4a5e-b263-81466a2ea6e5","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(2.660510, 2.718395]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[60.0],"label":["(2.660510, 2.718395]"],"line_alpha":[1.0], ...

# %%
#使用 bokeh.charts 的 Scatter() 方法。
from bokeh.charts import Scatter, show, output_notebook
import pandas as pd
output_notebook()
speed = [4, 4, 7, 7, 8, 9, 10, 10, 10, 11, 11, 12, 12, 12, 12, 13, 13, 13, 13, 14, 14, 14, 14, 15, 15, 15, 16, 16, 17, 17, 17, 18, 18, 18, 18, 19, 19, 19, 20, 20, 20, 20, 20, 22, 23, 24, 24, 24, 24, 25]
dist = [2, 10, 4, 22, 16, 10, 18, 26, 34, 17, 28, 14, 20, 24, 28, 26, 34, 34, 46, 26, 36, 60, 80, 20, 26, 54, 32, 40, 32, 40, 50, 42, 56, 76, 84, 36, 46, 68, 32, 48, 52, 56, 64, 66, 54, 70, 92, 93, 120, 85]

cars_df = pd.DataFrame(
    {"speed": speed,
     "dist": dist
    }
)

scatter = Scatter(cars_df, x = "speed", y = "dist")
show(scatter)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5f4c7d19-dcb5-4a93-bfd8-d3b4551c1daa">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="29c3193a-1df2-440b-89bd-0ad1f5f03226"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById
type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"} ...

# %%
#使用 bokeh.charts 的 Line() 方法。
from bokeh.charts import Line, show, output_notebook
import pandas as pd
output_notebook()
speed = [4, 4, 7, 7, 8, 9, 10, 10, 10, 11, 11, 12, 12, 12, 12, 13, 13, 13, 13, 14, 14, 14, 14, 15, 15, 15, 16, 16, 17, 17, 17, 18, 18, 18, 18, 19, 19, 19, 20, 20, 20, 20, 20, 22, 23, 24, 24, 24, 24, 25]
dist = [2, 10, 4, 22, 16, 10, 18, 26, 34, 17, 28, 14, 20, 24, 28, 26, 34, 34, 46, 26, 36, 60, 80, 20, 26, 54, 32, 40, 32, 40, 50, 42, 56, 76, 84, 36, 46, 68, 32, 48, 52, 56, 64, 66, 54, 70, 92, 93, 120, 85]

cars_df = pd.DataFrame(
    {"speed": speed,
     "dist": dist
    }
)

line = Line(cars_df, x = "speed", y = "dist")
show(line)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="127ca5de-d13d-4877-b59a-c150de0017e5">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8d8866a4-b79d-4aff-b996-6e67779a3765"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8d8866a4-b79d-4aff-b996-6e67779a3765");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8d8866a4-b79d-4aff-b996-6e67779a3765");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8d8866a4-b79d-4aff-b996-6e67779a3765' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a50f5174-9799-431f-836d-d0637cf170a2":{"roots":{"references":[{"attributes":{"location":"top_left","plot":{"id":"248d0f3d-75e6-4e71-b29d-cd672122c835","subtype":"Chart","type":"Plot"}},"id":"26ff4c58-3033-40a0-856b-99eccbe2451a","type":"Legend"},{"attributes":{"axis_label":"dist","formatter":{"id":"7a6c6172-3448-4003-b651-60788045b8b3","type":"BasicTickFormatter"},"plot":{"id":"248d0f3d-75e6-4e71-b29d-cd672122c835","subtype":"Chart","type":"Plot"},"ticker":{"id":"6c1c701a-1318-450d-ac88-2ac5cf9433ea","type":"BasicTicker"}},"id":"9bf1e930-2fc0-4f2b-87b7-0a2a09e70a52","type":"LinearAxis"},{"attributes":{},"id":"9291e479-404f-46a0-ab1b-b7f4f0c0c0d7","type":"BasicTicker"},{"attributes":{"plot":{"id":"248d0f3d-75e6-4e71-b29d-cd672122c835","subtype":"Chart","type":"Plot"},"ticker":{"id":"9291e479-404f-46a0-ab1b-b7f4f0c0c0d7","type":"BasicTicker"}},"id":"a2098c72-4a4d-4b55-b3ce-919bb77ff197","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[4,4,7,7,8,9,10,10,10,11,11,12,12,12,12,13,13,13,13,14,14,14,14,15,15,15,16,16,17,17,17,18,18,18,18,19,19,19,20,20,20,20,20,22,23,24,24,24,24,25],"y_values":[2,10,4,22,16,10,18,26,34,17,28,14,20,24,28,26,34,34,46,26,36,60,80,20,26,54,32,40,32,40,50,42,56,76,84,36,46,68,32,48,52,56,64,66,54,70,92,93,120,85]}},"id":"57645d6b-4798-4f94-bfe3-5aee4afbeb98","type":"ColumnDataSource"},{"attributes":{},"id":"6c1c701a-1318-450d-ac88-2ac5cf9433ea","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"248d0f3d-75e6-4e71-b29d-cd672122c835","subtype":"Chart","type":"Plot"},"ticker":{"id":"6c1c701a-1318-450d-ac88-2ac5cf9433ea","type":"BasicTicker"}},"id":"bd5414fc-df8c-4e90-88fc-07219f7eb4b8","type":"Grid"},{"attributes":{"callback":null,"end":131.8,"start":-9.8},"id":"6aa4093a-3f76-464d-9b84-736c8f34696e","type":"Range1d"},{"attributes":{"below":[{"id":"ff0bd5c8-135c-4532-a96d-4f0cf2d7e163","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"9bf1e930-2fc0-4f2b-87b7-0a2a09e70a52","type":"LinearAxis"}],"renderers":[{"id":"3fdc4649-3f83-4f66-972b-751c5de636ff","type":"BoxAnnotation"},{"id":"b3b59495-f58c-4237-9935-491bbd52e4a0","type":"GlyphRenderer"},{"id":"26ff4c58-3033-40a0-856b-99eccbe2451a","type":"Legend"},{"id":"ff0bd5c8-135c-4532-a96d-4f0cf2d7e163","type":"LinearAxis"},{"id":"9bf1e930-2fc0-4f2b-87b7-0a2a09e70a52","type":"LinearAxis"},{"id":"a2098c72-4a4d-4b55-b3ce-919bb77ff197","type":"Grid"},{"id":"bd5414fc-df8c-4e90-88fc-07219f7eb4b8","type":"Grid"}],"title":{"id":"2ecbfec2-aa27-4dd2-ac8e-4a8cc4bc30e8","type":"Title"},"tool_events":{"id":"a938777a-68e8-4139-bcc3-83ded5b4ea99","type":"ToolEvents"},"toolbar":{"id":"edcccf5a-82fa-4ee8-975e-ee51d5726a05","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"3bf77ba9-5865-4de4-96de-5dd50178a59b","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"6aa4093a-3f76-464d-9b84-736c8f34696e","type":"Range1d"}},"id":"248d0f3d-75e6-4e71-b29d-cd672122c835","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"a938777a-68e8-4139-bcc3-83ded5b4ea99","type":"ToolEvents"},{"attributes":{"plot":null,"text":null},"id":"2ecbfec2-aa27-4dd2-ac8e-4a8cc4bc30e8","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"068234d4-58c9-4ddd-bc99-1ffa71997bdd","type":"PanTool"},{"id":"a955a1aa-a6cc-4ac4-bd18-a53e48ac0f07","type":"WheelZoomTool"},{"id":"821b2f8e-cbda-43f7-bc54-facdeb6fead8","type":"BoxZoomTool"},{"id":"19de4f49-07bf-44fa-b898-d140c3b051f9","type":"SaveTool"},{"id":"7c695065-f5d0-466f-8983-35cf44aaa108","type":"ResetTool"},{"id":"24b6ca4d-258e-4699-aa4d-9f0fbdff69fb","type":"HelpTool"}]},"id":"edcccf5a-82fa-4ee8-975e-ee51d5726a05","type":"Toolbar"}, ...

# %%
#使用 bokeh.charts 的 Bar() 方法。
from bokeh.charts import Bar, show, output_notebook
import pandas as pd
output_notebook()
cyls = [11, 7, 14]
labels = ["4", "6", "8"]
cyl_df = pd.DataFrame({
    "cyl": cyls,
    "label": labels
})

bar = Bar(cyl_df, values = "cyl", label = "label")
show(bar)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="abc62cd9-35d9-44d2-b8fb-9396c291556f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="19fc04ef-7a38-478c-8d14-3571f84135ee"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("19fc04ef-7a38-478c-8d14-3571f84135ee");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("19fc04ef-7a38-478c-8d14-3571f84135ee");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '19fc04ef-7a38-478c-8d14-3571f84135ee' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a5703d9d-3987-4160-994d-13141ec7ee20":{"roots":{"references":[{"attributes":{"data_source":{"id":"81fd82db-5280-4706-9265-166a797acf28","type":"ColumnDataSource"},"glyph":{"id":"57a05d6a-ce12-4f9f-b8ae-89bf04cb2ee1","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"426eb56f-731f-4dfd-b035-989eb2fc201b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"6"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[7.0],"label":["6"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["6"],"y":[3.5]}},"id":"81fd82db-5280-4706-9265-166a797acf28","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"8"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[14.0],"label":["8"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["8"],"y":[7.0]}},"id":"25cf9a95-9039-478f-8f69-f47533b66a1f","type":"ColumnDataSource"},{"attributes":{},"id":"5c8a87e7-164c-4b5b-a649-511a4bee4697","type":"BasicTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"57a05d6a-ce12-4f9f-b8ae-89bf04cb2ee1","type":"Rect"},{"attributes":{"axis_label":"Sum( Cyl )","formatter":{"id":"6783c373-5399-49b6-8720-e2763bbd8dcf","type":"BasicTickFormatter"},"plot":{"id":"0f7ac158-fb7c-440f-9a8a-6a6e975a7e0b","subtype":"Chart","type":"Plot"},"ticker":{"id":"5c8a87e7-164c-4b5b-a649-511a4bee4697","type":"BasicTicker"}},"id":"5b0446ab-b16e-408e-a005-7d7f34b36342","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c4fe7608-cdc1-43e0-8b46-cf7138ed4775","type":"PanTool"},{"id":"0603b0df-26c5-42f7-944f-9a4a60fd740d","type":"WheelZoomTool"},{"id":"95bc83ec-1ca7-49ea-97d8-1626adbc209e","type":"BoxZoomTool"},{"id":"a2de9cd8-ce3b-4908-b43f-ac88cab3bdc4","type":"SaveTool"},{"id":"af409d51-67dc-4e70-8278-8e5a0d90f3c0","type":"ResetTool"},{"id":"e90b1ffb-8f50-4953-a4a0-3f45160918fb","type":"HelpTool"}]},"id":"86dbcaf7-eb5b-4186-bd42-b4975f153e30","type":"Toolbar"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"312b8e5e-bf49-4029-934f-ddcfa38b727b","type":"Rect"},{"attributes":{"callback":null,"factors":["4","6","8"]},"id":"4b4547a0-a887-46b4-8fe1-9949f0024640","type":"FactorRange"},{"attributes":{"label":{"value":"6"},"renderers":[{"id":"426eb56f-731f-4dfd-b035-989eb2fc201b","type":"GlyphRenderer"}]},"id":"6d994c3d-c360-418e-8675-1ee799b18ef2","type":"LegendItem"},{"attributes":{"plot":{"id":"0f7ac158-fb7c-440f-9a8a-6a6e975a7e0b","subtype":"Chart","type":"Plot"}},"id":"e90b1ffb-8f50-4953-a4a0-3f45160918fb","type":"HelpTool"},{"attributes":{"label":{"value":"8"},"renderers":[{"id":"45c88822-2cf1-4031-8e02-77aeb0ee36aa","type":"GlyphRenderer"}]},"id":"12c46907-ae8a-406c-b375-c7ee840e9c6e","type":"LegendItem"},{"attributes":{},"id":"6783c373-5399-49b6-8720-e2763bbd8dcf","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"0f7ac158-fb7c-440f-9a8a-6a6e975a7e0b","subtype":"Chart","type":"Plot"}},"id":"a2de9cd8-ce3b-4908-b43f-ac88cab3bdc4","type":"SaveTool"},{"attributes":{"data_source":{"id":"bcc4907b-fd5c-4e4b-95e6-e432c52e08a5","type":"ColumnDataSource"},"glyph":{"id":"ce2d8ff2-101d-466a-a9e6-478d8d2f5f13","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"c648d2f5-9b9e-4e75-a33b-7e5b5f45d6dd","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"0f7ac158-fb7c-440f-9a8a-6a6e975a7e0b","subtype":"Chart"," ...

# %%
#使用 bokeh.charts 的 BoxPlot() 方法。
from bokeh.charts import BoxPlot, show, output_notebook
import pandas as pd

output_notebook()

mpg = [21, 21, 22.8, 21.4, 18.7, 18.1, 14.3, 24.4, 22.8, 19.2, 17.8, 16.4, 17.3, 15.2, 10.4, 10.4, 14.7, 32.4, 30.4, 33.9, 21.5, 15.5, 15.2, 13.3, 19.2, 27.3, 26, 30.4, 15.8, 19.7, 15, 21.4]
cyl = [6, 6, 4, 6, 8, 6, 8, 4, 4, 6, 6, 8, 8, 8, 8, 8, 8, 4, 4, 4, 4, 8, 8, 8, 8, 4, 4, 4, 8, 6, 8, 4]
mtcars_df = pd.DataFrame({
    "mpg": mpg,
    "cyl": cyl
})

box = BoxPlot(mtcars_df, values = "mpg", label = "cyl")
show(box)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3884dcdd-af81-4dec-92b7-455fc8389162">Loading BokehJS ...</span>
#     </div>
# C:\Users\Java\Anaconda3\lib\site-packages\bokeh\core\json_encoder.py:73: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   if pd and isinstance(obj, pd.tslib.Timestamp):
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b77febaf-f973-4491-b700-f2570d3c65a8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b77febaf-f973-4491-b700-f2570d3c65a8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b77febaf-f973-4491-b700-f2570d3c65a8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b77febaf-f973-4491-b700-f2570d3c65a8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"08bfc7db-3d78-4ab0-a0ea-03c42cfeff06":{"roots":{"references":[{"attributes":{},"id":"93f014b4-14de-4a61-be3f-f3d7fcb06b8d","type":"BasicTicker"},{"attributes":{},"id":"64ba8b69-c218-4dc9-9943-81b864ba22d2","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a