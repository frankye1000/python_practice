# %%
import requests
import json

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36',
    'Cookie':'PHPSESSID=ohdk11rcvv8ggvu7iv27raqab6; T591_TOKEN=ohdk11rcvv8ggvu7iv27raqab6; urlJumpIp=5; urlJumpIpByTxt=%E6%96%B0%E7%AB%B9%E7%B8%A3; is_new_index=1; is_new_index_redirect=1; last_search_type=8; new_rent_list_kind_test=1; c10f3143a018a0513ebe1e8d27b5391c=1; _ga=GA1.3.1053328661.1507430031; _gid=GA1.3.1216437165.1507430031; _ga=GA1.4.1053328661.1507430031; _gid=GA1.4.1216437165.1507430031; 591_new_session=%3D%3D'    
}
res = requests.get('https://rent.591.com.tw/home/search/rsList?is_new_list=1&type=1&kind=0&searchtype=1&region=5&firstRow=0&totalRows=1587',headers = headers)
data = json.loads(res.text)
print(data)
# Out:
# {'status': 1, 'data': {'topData': [{'is_new_index': 0, 'is_new_list': 1, 'type': 1, 'post_id': 5661885, 'isAd': 0, 'regionid': 5, 'photoNum': 5, 'classLast': 'class = "last"', 'detail_url': 'rent-detail-5661885.html', 'address': '近明星技術學院近工業園區', 'img_src': 'https://hp1.591.com.tw/house/active/2017/07/23/150078014415083209_210x158.crop.jpg', 'alt': '新竹租屋,新豐租屋,獨立套房出租,近明星技術學院近工業園區', 'address_2': '近明星技術學院近工業園區', 'section_str': '新豐鄉', 'region': 5, 'kind_str': '獨立套房', 'area': '6坪', 'price_str': '4,800元', 'recom_num': 0, 'address_3': '近明星技術學院近..', 'ico': 'rent-ico', 'price': '4,800', 'price_unit': '元/月', 'onepxImg': ''}, {'is_new_index': 0, 'is_new_list': 1, 'type': 1, 'post_id': 5632097, 'isAd': 0, 'regionid': 5, 'photoNum': 15, 'classLast': '', 'detail_url': 'rent-detail-5632097.html', 'address': '湖口工業區內，近商店街超市夜市', 'img_src': 'https://hp2.591.com.tw/house/active/2016/05/19/146365971810081203_210x158.crop.jpg', 'alt': '新竹租屋,湖口租屋,整層住家出租,湖口工業區內，近商店街超市夜市', 'address_2': '湖口工業區內，近商店街超市...', 'sec
# ...
